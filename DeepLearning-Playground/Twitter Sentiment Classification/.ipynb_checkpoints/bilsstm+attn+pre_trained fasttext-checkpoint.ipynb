# %%
# DataFrame
import pandas as pd
from tqdm import tqdm_notebook, tnrange



# Matplot
import matplotlib.pyplot as plt
# %matplotlib inline

# Scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.manifold import TSNE
from sklearn.feature_extraction.text import TfidfVectorizer

# Keras
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Embedding, Flatten, Conv1D, MaxPooling1D, LSTM,Input
from keras import utils
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.layers import LSTM, Dense, Embedding, Bidirectional,GlobalMaxPool1D
from keras.layers import TimeDistributed
from keras.optimizers import Adam,Nadam
# nltk
import nltk
from nltk.corpus import stopwords
from  nltk.stem import SnowballStemmer

# Word2vec
import gensim

# Utility
import re
import numpy as np
import os
from collections import Counter
import logging
import time
import pickle
import itertools

# Set log
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
filepath = 'ModelCheckpoint/Bi_LSTM_Ensemble.{epoch:02d}-{val_acc:.3f}.hdf5'
# Out:
# /Users/subir/anaconda3/envs/DeepLearning/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# Using TensorFlow backend.

# %%
# DATASET
TRAIN_SIZE = 0.8

# TEXT CLENAING
TEXT_CLEANING_RE = "@\S+|https?:\S+|http?:\S|[^A-Za-z0-9]+"

# WORD2VEC 
W2V_SIZE = 300
W2V_WINDOW = 7
W2V_EPOCH = 50
W2V_MIN_COUNT = 5

# KERAS
SEQUENCE_LENGTH = 100
EPOCHS = 50
BATCH_SIZE = 128

# SENTIMENT
POSITIVE = "POSITIVE"
NEGATIVE = "HATE"
SENTIMENT_THRESHOLDS = 0.4

# EXPORT
KERAS_MODEL = "model.h5"
WORD2VEC_MODEL = "model.w2v"
TOKENIZER_MODEL = "tokenizer.pkl"
ENCODER_MODEL = "encoder.pkl"

# %%
train=pd.read_csv('./data/train_E6oV3lV.csv')
test=pd.read_csv('./data/test_tweets_anuFYb8.csv')

# %%
train.head()
train=train.sample(frac=1)

# %%
combi = train.append(test, ignore_index=True,sort=False)

# %%
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for i in r:
        input_txt = re.sub(i, '', input_txt)
        
    return input_txt

# %%
# remove twitter handles (@user)
combi['tidy_tweet'] = np.vectorize(remove_pattern)(combi['tweet'], "@[\w]*")

# %%
# remove special characters, numbers, punctuations
combi['tidy_tweet'] = combi['tidy_tweet'].str.replace("[^a-zA-Z#]", " ")

# %%
combi['tidy_tweet'] = combi['tidy_tweet'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>2]))

# %%
combi['tidy_tweet'] = combi['tidy_tweet'].str.replace('#',' Hashtag ')

# %%
train.shape , test.shape ,combi.shape
# Out:
# ((31962, 3), (17197, 2), (49159, 4))

# %%
tokenized_tweet = combi['tidy_tweet'].apply(lambda x: x.split())
tokenized_tweet.head()
# Out:
# 0    [just, over, months, stopping, for, lunch, exe...
# 1    [electrocheking, out, some, blues, Hashtag, mu...
# 2                                         [miss, much]
# 3    [bottom, line, think, about, you, and, your, s...
# 4              [bihday, hope, enjoy, your, day, proud]
# Name: tidy_tweet, dtype: object

# %%
from nltk.stem.porter import *
from nltk.stem.wordnet import WordNetLemmatizer
stemmer = PorterStemmer()
lmtzr = WordNetLemmatizer()

tokenized_tweet = tokenized_tweet.apply(lambda x: [stemmer.stem(i) for i in x]) # stemming
tokenized_tweet = tokenized_tweet.apply(lambda x: [lmtzr.lemmatize(i) for i in x]) #lemmatize 
tokenized_tweet.head()
# Out:
# 0    [just, over, month, stop, for, lunch, exet, pr...
# 1    [electrochek, out, some, blue, hashtag, musica...
# 2                                         [miss, much]
# 3    [bottom, line, think, about, you, and, your, s...
# 4              [bihday, hope, enjoy, your, day, proud]
# Name: tidy_tweet, dtype: object

# %%
for i in range(len(tokenized_tweet)):
    tokenized_tweet[i] = ' '.join(tokenized_tweet[i])

combi['tidy_tweet'] = tokenized_tweet

# %%
all_words = ' '.join([text for text in combi['tidy_tweet']])
from wordcloud import WordCloud
import matplotlib.pyplot as plt
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
normal_words =' '.join([text for text in combi['tidy_tweet'][combi['label'] == 0]])

wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(normal_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
negative_words = ' '.join([text for text in combi['tidy_tweet'][combi['label'] == 1]])
wordcloud = WordCloud(width=800, height=500,
random_state=21, max_font_size=110).generate(negative_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
# %%time
import gensim

from gensim.models import FastText , Word2Vec
documents = [_text.split() for _text in combi.tidy_tweet]
# Out:
# CPU times: user 88.6 ms, sys: 22.4 ms, total: 111 ms
# Wall time: 112 ms

# %%
# WORD2VEC 
W2V_SIZE = 200  #100
W2V_WINDOW = 5  #7
W2V_EPOCH = 50  #32
W2V_MIN_COUNT = 5  #5
w2v_model = Word2Vec(size=W2V_SIZE, window=W2V_WINDOW, min_count=W2V_MIN_COUNT, workers=16)

w2v_model.build_vocab(documents)
# Out:
# 2019-03-02 12:35:59,747 : INFO : collecting all words and their counts
# 2019-03-02 12:35:59,748 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-03-02 12:35:59,780 : INFO : PROGRESS: at sentence #10000, processed 122280 words, keeping 14766 word types
# 2019-03-02 12:35:59,812 : INFO : PROGRESS: at sentence #20000, processed 244082 words, keeping 23019 word types
# 2019-03-02 12:35:59,840 : INFO : PROGRESS: at sentence #30000, processed 365083 words, keeping 30034 word types
# 2019-03-02 12:35:59,873 : INFO : PROGRESS: at sentence #40000, processed 486581 words, keeping 36004 word types
# 2019-03-02 12:35:59,897 : INFO : collected 40953 word types from a corpus of 598043 raw words and 49159 sentences
# 2019-03-02 12:35:59,898 : INFO : Loading a fresh vocabulary
# 2019-03-02 12:35:59,927 : INFO : effective_min_count=5 retains 6823 unique words (16% of original 40953, drops 34130)
# 2019-03-02 12:35:59,927 : INFO : effective_min_count=5 leaves 550133 word corpus (91% of original 598043, drops 47910)
# 2019-03-02 12:35:59,952 : INFO : deleting the raw counts dictionary of 40953 items
# 2019-03-02 12:35:59,953 : INFO : sample=0.001 downsamples 36 most-common words
# 2019-03-02 12:35:59,953 : INFO : downsampling leaves estimated 393442 word corpus (71.5% of prior 550133)
# 2019-03-02 12:35:59,973 : INFO : estimated required memory for 6823 words and 200 dimensions: 14328300 bytes
# 2019-03-02 12:35:59,974 : INFO : resetting layer weights

# %%
model_fb = FastText(size=W2V_SIZE, window=W2V_WINDOW, min_count=W2V_MIN_COUNT, workers=16)
model_fb.build_vocab(documents)
# Out:
# 2019-02-24 09:39:48,620 : INFO : resetting layer weights
# 2019-02-24 09:39:48,621 : INFO : Total number of ngrams is 0
# 2019-02-24 09:39:48,622 : INFO : collecting all words and their counts
# 2019-02-24 09:39:48,623 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-02-24 09:39:48,652 : INFO : PROGRESS: at sentence #10000, processed 121223 words, keeping 14969 word types
# 2019-02-24 09:39:48,690 : INFO : PROGRESS: at sentence #20000, processed 243366 words, keeping 23164 word types
# 2019-02-24 09:39:48,728 : INFO : PROGRESS: at sentence #30000, processed 365235 words, keeping 29970 word types
# 2019-02-24 09:39:48,753 : INFO : PROGRESS: at sentence #40000, processed 486581 words, keeping 36004 word types
# 2019-02-24 09:39:48,777 : INFO : collected 40953 word types from a corpus of 598043 raw words and 49159 sentences
# 2019-02-24 09:39:48,779 : INFO : Loading a fresh vocabulary
# 2019-02-24 09:39:48,804 : INFO : effective_min_count=5 retains 6823 unique words (16% of original 40953, drops 34130)
# 2019-02-24 09:39:48,805 : INFO : effective_min_count=5 leaves 550133 word corpus (91% of original 598043, drops 47910)
# 2019-02-24 09:39:48,825 : INFO : deleting the raw counts dictionary of 40953 items
# 2019-02-24 09:39:48,826 : INFO : sample=0.001 downsamples 36 most-common words
# 2019-02-24 09:39:48,828 : INFO : downsampling leaves estimated 393442 word corpus (71.5% of prior 550133)
# 2019-02-24 09:39:48,901 : INFO : estimated required memory for 6823 words, 53620 buckets and 200 dimensions: 58516348 bytes
# 2019-02-24 09:39:48,903 : INFO : resetting layer weights
# 2019-02-24 09:39:49,069 : INFO : Total number of ngrams is 53620

# %%
# %%time
words = model_fb.wv.vocab.keys()
vocab_size = len(words)
print("Vocab size", vocab_size)
model_fb.train(documents, total_examples=len(documents), epochs=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>()
#
# NameError: name 'model_fb' is not defined

# %%
# %%time
words = w2v_model.wv.vocab.keys()
vocab_size = len(words)
print("Vocab size", vocab_size)
w2v_model.train(documents, total_examples=len(documents), epochs=2)
# Out:
# 2019-03-02 12:36:14,621 : INFO : training model with 16 workers on 6823 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# Vocab size 6823
# 2019-03-02 12:36:16,191 : INFO : EPOCH 1 - PROGRESS: at 1.61% examples, 4264 words/s, in_qsize 31, out_qsize 0
# 2019-03-02 12:36:18,006 : INFO : EPOCH 1 - PROGRESS: at 28.27% examples, 33237 words/s, in_qsize 31, out_qsize 0
# 2019-03-02 12:36:19,753 : INFO : EPOCH 1 - PROGRESS: at 55.09% examples, 42435 words/s, in_qsize 27, out_qsize 0
# 2019-03-02 12:36:20,099 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-03-02 12:36:20,105 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-03-02 12:36:20,128 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-03-02 12:36:20,150 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-03-02 12:36:21,226 : INFO : EPOCH 1 - PROGRESS: at 81.63% examples, 48773 words/s, in_qsize 11, out_qsize 1
# 2019-03-02 12:36:21,227 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-03-02 12:36:21,228 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-03-02 12:36:21,280 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-03-02 12:36:21,281 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-03-02 12:36:21,286 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-03-02 12:36:21,314 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-03-02 12:36:21,328 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-03-02 12:36:21,350 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-03-02 12:36:21,351 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-03-02 12:36:21,353 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-03-02 12:36:21,354 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-03-02 12:36:21,355 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-03-02 12:36:21,356 : INFO : EPOCH - 1 : training on 598043 raw words (393349 effective words) took 6.7s, 58543 effective words/s
# 2019-03-02 12:36:23,114 : INFO : EPOCH 2 - PROGRESS: at 1.61% examples, 3816 words/s, in_qsize 31, out_qsize 0
# 2019-03-02 12:36:25,030 : INFO : EPOCH 2 - PROGRESS: at 28.27% examples, 30579 words/s, in_qsize 32, out_qsize 0
# 2019-03-02 12:36:26,750 : INFO : EPOCH 2 - PROGRESS: at 55.09% examples, 40335 words/s, in_qsize 27, out_qsize 0
# 2019-03-02 12:36:26,905 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-03-02 12:36:26,908 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-03-02 12:36:26,909 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-03-02 12:36:26,910 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-03-02 12:36:28,079 : INFO : EPOCH 2 - PROGRESS: at 81.63% examples, 47905 words/s, in_qsize 11, out_qsize 1
# 2019-03-02 12:36:28,079 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-03-02 12:36:28,135 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-03-02 12:36:28,161 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-03-02 12:36:28,185 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-03-02 12:36:28,193 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-03-02 12:36:28,196 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-03-02 12:36:28,218 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-03-02 12:36:28,220 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-03-02 12:36:28,223 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-03-02 12:36:28,226 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-03-02 12:36:28,230 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-03-02 12:36:28,231 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-03-02 12:36:28,232 : INFO : EPOCH - 2 : training on 598043 raw words (393619 effective words) took 6.9s, 57365 effective words/s
# 2019-03-02 12:36:28,233 : INFO : training on a 1196086 raw words (786968 effective words) took 13.6s, 57819 effective words/s
# 2019-03-02 12:36:28,235 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# CPU times: user 52.3 s, sys: 90.5 ms, total: 52.4 s
# Wall time: 13.6 s

# %%
model_fb.most_similar("hate")
# Out:
# /Users/subir/anaconda3/envs/DeepLearning/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# 2019-02-24 10:17:33,234 : INFO : precomputing L2-norms of word weight vectors
# 2019-02-24 10:17:33,242 : INFO : precomputing L2-norms of ngram weight vectors
# [('hatecrim', 0.7926521301269531),
#  ('hater', 0.7308928370475769),
#  ('hatr', 0.6715140342712402),
#  ('hat', 0.646233320236206),
#  ('hatespeech', 0.5973802804946899),
#  ('ate', 0.4574719965457916),
#  ('nonsens', 0.44881898164749146),
#  ('islamophob', 0.4178704023361206),
#  ('asshat', 0.409171998500824),
#  ('religi', 0.40672698616981506)]

# %%
w2v_model.most_similar("hate")
# Out:
# /Users/subir/anaconda3/envs/DeepLearning/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# 2019-03-02 12:36:32,129 : INFO : precomputing L2-norms of word weight vectors
# [('shit', 0.9971246719360352),
#  ('anyon', 0.9969261884689331),
#  ('pretend', 0.9965639710426331),
#  ('where', 0.9965607523918152),
#  ('said', 0.996532142162323),
#  ('understand', 0.9964431524276733),
#  ('nigga', 0.9955431222915649),
#  ('assum', 0.9954929351806641),
#  ('el', 0.9954491853713989),
#  ('should', 0.9951863288879395)]

# %%
EMBEDDING_FILE = '/Users/subir/WordEmbeddings/glove.840B.300d.txt'
def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')
embeddings_index = dict(get_coefs(*o.split(" ")) for o in open(EMBEDDING_FILE))

all_embs = np.stack(embeddings_index.values())
emb_mean,emb_std = all_embs.mean(), all_embs.std()
embed_size = all_embs.shape[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-3bbb660f8e72> in <module>()
#       7 embed_size = all_embs.shape[1]
#       8
# ----> 9 word_index = tokenizer.word_index
#
# NameError: name 'tokenizer' is not defined

# %%
embedding_matrix.shape
# Out:
# (31217, 300)

# %%
df_train=combi[:len(train)]
df_test=combi[len(train):]

# %%
df_train.shape ,df_test.shape
# Out:
# ((31962, 4), (17197, 4))

# %%
df_train.head()
# Out:
#       id  label                                              tweet  \
# 0  21092    0.0  in just over 2 months, we'll be stopping for l...
# 1   7804    0.0  electrocheking out some blues. #musicalveneus ...
# 2  19526    0.0                       @user i miss @user so much
# 3  19612    0.0  @user @user ....bottom line...think about you ...
# 4   9584    0.0  @user   bihdayð°ðððððhope u e...
#
#                                           tidy_tweet
# 0  just over month stop for lunch exet premium di...
# 1  electrochek out some blue hashtag musicalveneu...
# 2                                          miss much
# 3  bottom line think about you and your safeti th...
# 4                   bihday hope enjoy your day proud

# %%
df_train.label.value_counts()
# Out:
# 0.0    29720
# 1.0     2242
# Name: label, dtype: int64

# %%
df_test.drop('label',1,inplace=True)
# Out:
# /Users/subir/anaconda3/envs/DeepLearning/lib/python3.6/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
df_test.head()
# Out:
#           id                                              tweet  \
# 31962  31963  #studiolife #aislife #requires #passion #dedic...
# 31963  31964   @user #white #supremacists want everyone to s...
# 31964  31965  safe ways to heal your #acne!!    #altwaystohe...
# 31965  31966  is the hp and the cursed child book up for res...
# 31966  31967    3rd #bihday to my amazing, hilarious #nephew...
#
#                                               tidy_tweet
# 31962  hashtag studiolif hashtag aislif hashtag requi...
# 31963  hashtag white hashtag supremacist want everyon...
# 31964  safe way heal your hashtag acn hashtag altways...
# 31965  the and the cur child book for reserv alreadi ...
# 31966  hashtag bihday amaz hilari hashtag nephew eli ...

# %%
# Data providers
# batch_size = 128

# def batch_gen(train_df):
#     n_batches = math.ceil(len(train_df) / batch_size)
#     while True: 
#         train_df = train_df.sample(frac=1.)  # Shuffle the data.
#         for i in range(n_batches):
#             texts = train_df.iloc[i*batch_size:(i+1)*batch_size, 1]
#             text_arr = np.array([text_to_array(text) for text in texts])
#             yield text_arr, np.array(train_df["target"][i*batch_size:(i+1)*batch_size])

# %%
# %%time
x_train = pad_sequences(tokenizer.texts_to_sequences(df_train.tidy_tweet), maxlen=SEQUENCE_LENGTH)
x_test = pad_sequences(tokenizer.texts_to_sequences(df_test.tidy_tweet), maxlen=SEQUENCE_LENGTH)
# Out:
# CPU times: user 920 ms, sys: 11.4 ms, total: 932 ms
# Wall time: 934 ms

# %%
print(x_train.shape)
# Out:
# (31962, 100)

# %%
word_index = tokenizer.word_index
embed_size = 300 # how big is each word vector
max_features = 50000 # how many unique words to use (i.e num rows in embedding vector)
maxlen = 100 # max number of words in a question to use

tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(df_train.tidy_tweet)

vocab_size = len(tokenizer.word_index)
print("Total words", vocab_size)
nb_words = min(max_features, len(word_index))+1
embedding_matrix = np.random.normal(emb_mean, emb_std, (nb_words, embed_size))
for word, i in word_index.items():
    if i >= max_features: continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None: embedding_matrix[i] = embedding_vector
        
print(embedding_matrix.shape)
# Out:
# Total words 31217
# (31218, 300)

# %%
encoder = LabelEncoder()
encoder.fit(df_train.label.tolist())
y_train = encoder.transform(df_train.label.tolist())
y_train = y_train.reshape(-1,1)
print("y_train",y_train.shape)
# Out:
# y_train (31962, 1)

# %%
embedding_layer = Embedding(nb_words, embed_size, weights=[embedding_matrix], input_length=SEQUENCE_LENGTH, trainable=False)

# %%
from keras.engine.topology import Layer
import keras.backend as K
from keras import initializers, regularizers, constraints, optimizers, layers
class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %%
model = Sequential()
model.add(embedding_layer)
model.add(Bidirectional(LSTM(100, dropout=0.2, recurrent_dropout=0.2,return_sequences=True)))
model.add(TimeDistributed(Dense(100, use_bias=True)))
model.add(Attention(SEQUENCE_LENGTH))
model.add(Dense(100,activation='elu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_9 (Embedding)      (None, 100, 300)          9365400
# _________________________________________________________________
# bidirectional_6 (Bidirection (None, 100, 200)          320800
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, 100, 100)          20100
# _________________________________________________________________
# attention_6 (Attention)      (None, 100)               200
# _________________________________________________________________
# dense_15 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 9,716,701
# Trainable params: 351,301
# Non-trainable params: 9,365,400
# _________________________________________________________________

# %%
def binary_focal_loss(gamma=2., alpha=.25):
    """
    Binary form of focal loss.
      FL(p_t) = -alpha * (1 - p_t)**gamma * log(p_t)
      where p = sigmoid(x), p_t = p or 1 - p depending on if the label is 1 or 0, respectively.
    References:
        https://arxiv.org/pdf/1708.02002.pdf
    Usage:
     model.compile(loss=[binary_focal_loss(alpha=.25, gamma=2)], metrics=["accuracy"], optimizer=adam)
    """
    def binary_focal_loss_fixed(y_true, y_pred):
        """
        :param y_true: A tensor of the same shape as `y_pred`
        :param y_pred:  A tensor resulting from a sigmoid
        :return: Output tensor.
        """
        pt_1 = tf.where(tf.equal(y_true, 1), y_pred, tf.ones_like(y_pred))
        pt_0 = tf.where(tf.equal(y_true, 0), y_pred, tf.zeros_like(y_pred))

        epsilon = K.epsilon()
        # clip to prevent NaN's and Inf's
        pt_1 = K.clip(pt_1, epsilon, 1. - epsilon)
        pt_0 = K.clip(pt_0, epsilon, 1. - epsilon)

        return -K.sum(alpha * K.pow(1. - pt_1, gamma) * K.log(pt_1)) \
               -K.sum((1 - alpha) * K.pow(pt_0, gamma) * K.log(1. - pt_0))

    return binary_focal_loss_fixed

# %%
from keras import backend as K
import tensorflow as tf
model.compile(optimizer='adam',metrics=['accuracy'],loss=[binary_focal_loss()])

# %%
callbacks = [ReduceLROnPlateau(monitor='val_acc', patience=5, cooldown=0,verbose=1,factor=0.5),
            TensorBoard(log_dir='./Graph',batch_size=BATCH_SIZE, write_graph=True, write_images=True),
            ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')]

# %%
# %%time
history = model.fit(x_train, y_train,
                    batch_size=128,
                    epochs=50,
                    validation_split=0.2,
                    verbose=1,
                    callbacks=callbacks)
# Out:
# Train on 25569 samples, validate on 6393 samples
# Epoch 1/50
# 25569/25569 [==============================] - 106s 4ms/step - loss: 1.7082 - acc: 0.9510 - val_loss: 1.7116 - val_acc: 0.9509
#
# Epoch 00001: val_acc improved from 0.94603 to 0.95088, saving model to ModelCheckpoint/Bi_LSTM_Ensemble.01-0.951.hdf5
# Epoch 2/50
# 25569/25569 [==============================] - 106s 4ms/step - loss: 1.4544 - acc: 0.9578 - val_loss: 1.6801 - val_acc: 0.9537
#
# Epoch 00002: val_acc improved from 0.95088 to 0.95370, saving model to ModelCheckpoint/Bi_LSTM_Ensemble.02-0.954.hdf5
# Epoch 3/50
# 25569/25569 [==============================] - 109s 4ms/step - loss: 1.2415 - acc: 0.9635 - val_loss: 1.7672 - val_acc: 0.9587
#
# Epoch 00003: val_acc improved from 0.95370 to 0.95870, saving model to ModelCheckpoint/Bi_LSTM_Ensemble.03-0.959.hdf5
# Epoch 4/50
# 25569/25569 [==============================] - 111s 4ms/step - loss: 1.0798 - acc: 0.9680 - val_loss: 1.6641 - val_acc: 0.9537
#
# Epoch 00004: val_acc did not improve from 0.95870
# Epoch 5/50
# 25569/25569 [==============================] - 105s 4ms/step - loss: 0.9283 - acc: 0.9723 - val_loss: 1.7369 - val_acc: 0.9596
#
# Epoch 00005: val_acc improved from 0.95870 to 0.95964, saving model to ModelCheckpoint/Bi_LSTM_Ensemble.05-0.960.hdf5
# Epoch 6/50
# 25569/25569 [==============================] - 108s 4ms/step - loss: 0.7659 - acc: 0.9768 - val_loss: 1.9560 - val_acc: 0.9609
#
# Epoch 00006: val_acc improved from 0.95964 to 0.96089, saving model to ModelCheckpoint/Bi_LSTM_Ensemble.06-0.961.hdf5
# Epoch 7/50
# 25569/25569 [==============================] - 116s 5ms/step - loss: 0.6214 - acc: 0.9820 - val_loss: 2.1310 - val_acc: 0.9621
#
# Epoch 00007: val_acc improved from 0.96089 to 0.96215, saving model to ModelCheckpoint/Bi_LSTM_Ensemble.07-0.962.hdf5
# Epoch 8/50
# 25569/25569 [==============================] - 115s 4ms/step - loss: 0.5421 - acc: 0.9838 - val_loss: 2.3240 - val_acc: 0.9598
#
# Epoch 00008: val_acc did not improve from 0.96215
# Epoch 9/50
# 25569/25569 [==============================] - 115s 5ms/step - loss: 0.4695 - acc: 0.9862 - val_loss: 2.5354 - val_acc: 0.9603
#
# Epoch 00009: val_acc did not improve from 0.96215
# Epoch 10/50
# 25569/25569 [==============================] - 121s 5ms/step - loss: 0.4040 - acc: 0.9875 - val_loss: 2.9062 - val_acc: 0.9600
#
# Epoch 00010: val_acc did not improve from 0.96215
# Epoch 11/50
# 25569/25569 [==============================] - 121s 5ms/step - loss: 0.3559 - acc: 0.9889 - val_loss: 2.9502 - val_acc: 0.9625
#
# Epoch 00011: val_acc improved from 0.96215 to 0.96246, saving model to ModelCheckpoint/Bi_LSTM_Ensemble.11-0.962.hdf5
# Epoch 12/50
# 25569/25569 [==============================] - 119s 5ms/step - loss: 0.3177 - acc: 0.9909 - val_loss: 3.0260 - val_acc: 0.9631
#
# Epoch 00012: val_acc improved from 0.96246 to 0.96308, saving model to ModelCheckpoint/Bi_LSTM_Ensemble.12-0.963.hdf5
# Epoch 13/50
# 25569/25569 [==============================] - 130s 5ms/step - loss: 0.2946 - acc: 0.9917 - val_loss: 2.7156 - val_acc: 0.9629
#
# Epoch 00013: val_acc did not improve from 0.96308
# Epoch 14/50
#  6656/25569 [======>.......................] - ETA: 1:23 - loss: 0.2684 - acc: 0.9934
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>()
#
# ~/anaconda3/envs/DeepLearning/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/envs/DeepLearning/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/envs/DeepLearning/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/envs/DeepLearning/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/anaconda3/envs/DeepLearning/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args)
#    1449         if self._session._created_with_new_api:
#    1450           return tf_session.TF_SessionRunCallable(
# -> 1451               self._session._session, self._handle, args, status, None)
#    1452         else:
#    1453           return tf_session.TF_DeprecatedSessionRunCallable(
#
# KeyboardInterrupt:

# %%
def decode_sentiment(score):
    if float(score)>0.3:
        return 1
    else:
        return 0
def predict(row):
  
    start_at = time.time()
    # Tokenize text
    x_test = pad_sequences(tokenizer.texts_to_sequences([row['tidy_tweet']]), maxlen=SEQUENCE_LENGTH)
    # Predict
    score = model.predict([x_test])[0]
    # Decode sentiment
    label = decode_sentiment(score)
    row['label']=label
    return row

# %%
from tqdm import tqdm ,tqdm_pandas
new_test = df_test.apply(predict,1)

# %%
new_test.head()
# Out:
#           id                                              tweet  \
# 31962  31963  #studiolife #aislife #requires #passion #dedic...
# 31963  31964   @user #white #supremacists want everyone to s...
# 31964  31965  safe ways to heal your #acne!!    #altwaystohe...
# 31965  31966  is the hp and the cursed child book up for res...
# 31966  31967    3rd #bihday to my amazing, hilarious #nephew...
#
#                                               tidy_tweet  label
# 31962  hashtag studiolif hashtag aislif hashtag requi...      0
# 31963  hashtag white hashtag supremacist want everyon...      0
# 31964  safe way heal your hashtag acn hashtag altways...      0
# 31965  the and the cur child book for reserv alreadi ...      0
# 31966  hashtag bihday amaz hilari hashtag nephew eli ...      0

# %%
new_test.label.value_counts()
# Out:
# 0    16057
# 1     1140
# Name: label, dtype: int64

# %%
new_test.drop('tweet',1,inplace=True)

# %%
new_test.drop('tidy_tweet',1,inplace=True)

# %%
new_test.to_csv('new_sub1.csv',index=False)
