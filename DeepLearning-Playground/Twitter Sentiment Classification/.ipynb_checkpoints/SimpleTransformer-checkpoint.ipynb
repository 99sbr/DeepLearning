# %%
# DataFrame
import pandas as pd
pd.set_option('display.max_colwidth', -1)
from tqdm import tqdm_notebook, tnrange

# Matplot
import matplotlib.pyplot as plt
# %matplotlib inline

# Scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.manifold import TSNE
from sklearn.feature_extraction.text import TfidfVectorizer

# Keras
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Embedding, Flatten, Conv1D, MaxPooling1D, LSTM,Input
from keras import utils
from keras.callbacks import ReduceLROnPlateau, EarlyStopping , CSVLogger
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.layers import LSTM, Dense, Embedding, Bidirectional,GlobalMaxPool1D, Lambda
from keras.layers import TimeDistributed
from keras.layers import *
from keras.optimizers import Adam,Nadam

# nltk
import nltk
from nltk.corpus import stopwords
from  nltk.stem import SnowballStemmer

# Word2vec
import gensim
# Utility
import re
import numpy as np
import os
from collections import Counter
import logging
import time
import pickle
import itertools

#spacy
import wordninja
from nltk.tokenize import TweetTokenizer
stop_words = set(stopwords.words('english'))
tknzr = TweetTokenizer()
# import spaCy's language model
import spacy
nlp = spacy.load('en_core_web_lg', disable=['parser', 'ner'])
tokenizer = nlp.Defaults.create_tokenizer(nlp)

# import tensorflow_hub as hub
# import tensorflow as tf
# elmo = hub.Module("https://tfhub.dev/google/elmo/2", trainable=True)
# Out:
# /Users/subir/pythonenv/default/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
train=pd.read_csv('./data/train_E6oV3lV.csv')
test=pd.read_csv('./data/test_tweets_anuFYb8.csv')

# %%
train.head()
train=train.sample(frac=1)

# %%
train.label.value_counts()
# Out:
# 0    29720
# 1    13452
# Name: label, dtype: int64

# %%
combi = train.append(test, ignore_index=True,sort=False)

# %%
# remove special characters, numbers, punctuations
import contractions
combi['tidy_tweet'] = combi['tweet'].apply(
    lambda x: [contractions.fix(word) for word in x.split()])

combi['tidy_tweet'] = combi['tidy_tweet'].apply(lambda x: ' '.join(x))
combi['tidy_tweet'] = combi['tidy_tweet'].str.replace("@user", "")
combi['tidy_tweet'] = combi['tidy_tweet'].str.replace("[^a-zA-Z0-9#]", " ")
combi['tidy_tweet'] = combi['tidy_tweet'].str.replace('#', 'hashtag ')

# %%
combi.head()
# Out:
#       id label  \
# 0  9593   0
# 1  874    0
# 2  5157   0
# 3  10441  0
# 4  30134  1
#
#                                                                                                                     tweet  \
# 0  be   you are #blessed #blessedtoseeanotherday #liveandletlive #prayformycityâ¦
# 1  @user loving our dincwear! mum's da word @user for straight up '16 on saturday   #brickingit
# 2  @user @user for the life of me i do t know why people must be defined by their sexuality!! why can't they just be ð¢
# 3  ð   #tech bitcoin coolwallet review â itâs indeed a cool wallet
# 4  time to #grabyourwallet  &amp; boycott @user who gives book deal to  troll banned by twitter
#
#                                                                                                        tidy_tweet
# 0  be you are hashtag blessed hashtag blessedtoseeanotherday hashtag liveandletlive hashtag prayformycity
# 1   loving our dincwear  mum s da word  for straight up  16 on saturday hashtag brickingit
# 2    for the life of me i do t know why people must be defined by their sexuality   why can not they just be
# 3       hashtag tech bitcoin coolwallet review     it   s indeed a cool wallet
# 4  time to hashtag grabyourwallet  amp  boycott  who gives book deal to troll banned by twitter

# %%
combi.tidy_tweet = combi.tidy_tweet.apply(lambda x: tknzr.tokenize(x))
combi.tidy_tweet = combi.tidy_tweet.apply(lambda x: [word for word in x if word not in stop_words])

# %%
combi.tidy_tweet = combi.tidy_tweet.apply(lambda x: [wordninja.split(word) for word in x if word not in 'hashtag'])

# %%
combi.tidy_tweet = combi.tidy_tweet.apply(lambda x:[item for sublist in x for item in sublist] )

# %%
combi.tidy_tweet = combi.tidy_tweet.apply(lambda x:' '.join(x))

# %%
combi.head(10)
# Out:
#       id label  \
# 0  9593   0
# 1  874    0
# 2  5157   0
# 3  10441  0
# 4  30134  1
# 5  13401  0
# 6  17293  0
# 7  8171   1
# 8  29175  0
# 9  19116  1
#
#                                                                                                                     tweet  \
# 0  be   you are #blessed #blessedtoseeanotherday #liveandletlive #prayformycityâ¦
# 1  @user loving our dincwear! mum's da word @user for straight up '16 on saturday   #brickingit
# 2  @user @user for the life of me i do t know why people must be defined by their sexuality!! why can't they just be ð¢
# 3  ð   #tech bitcoin coolwallet review â itâs indeed a cool wallet
# 4  time to #grabyourwallet  &amp; boycott @user who gives book deal to  troll banned by twitter
# 5  @user chicken breast with homemade bbq sauce, and sauteed garlic spinach.
# 6  yesterday i won the prize for best paper presentation at the beta @user phd seminar ð   #proud #unexpected
# 7  this is a completely justified call out on my comment. again i do apologize @user
# 8  no-one knows what goes on behind closed doors and this woman like a book is judged by her cover.   #heabreaking
# 9  are you #hispanic &amp; feel like the  are â¦ on you? listen  #retweet #boricua #miamiâ¦
#
#                                                                       tidy_tweet
# 0  blessed blessed to see another day live and let live pray for my city
# 1  loving d inc wear mum da word straight 16 saturday bricking it
# 2  life know people must defined sexuality
# 3  tech bitcoin cool wallet review indeed cool wallet
# 4  time grab your wallet amp boycott gives book deal troll banned twitter
# 5  chicken breast homemade bbq sauce sau teed garlic spinach
# 6  yesterday prize best paper presentation beta phd seminar proud unexpected
# 7  completely justified call comment apologize
# 8  one knows goes behind closed doors woman like book judged cover he a breaking
# 9  hispanic amp feel like listen re tweet boricua miami

# %%
# %%time
# function to lemmatize text
def lemmatization(texts):
    output = []
    for i in texts:
        s = [token.lemma_ for token in nlp(i)]
        output.append(' '.join(s))
    return output
combi.tidy_tweet = lemmatization(combi.tidy_tweet)
# Out:
# CPU times: user 1min 58s, sys: 1.62 s, total: 1min 59s
# Wall time: 2min 2s

# %%
combi.tidy_tweet = combi.tidy_tweet.apply(lambda x : [word for word in x.split() if len(word)>1])

# %%
import seaborn as sns
combi['doc_len'] = combi['tidy_tweet'].apply(lambda words: len(words))
max_seq_len = np.round(combi['doc_len'].mean() + combi['doc_len'].std()).astype(int)
sns.distplot(combi['doc_len'], hist=True, kde=True, color='b', label='doc len')
plt.axvline(x=max_seq_len, color='k', linestyle='--', label='max len')
plt.title('comment length'); plt.legend()
plt.show()

# %%
combi['tidy_tweet'] = combi['tidy_tweet'].apply(lambda x: ' '.join(x))

# %%
all_words = ' '.join([text for text in combi['tidy_tweet']])
from wordcloud import WordCloud
import matplotlib.pyplot as plt
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
normal_words =' '.join([text for text in combi['tidy_tweet'][combi['label'] == 0]])

wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(normal_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
negative_words = ' '.join([text for text in combi['tidy_tweet'][combi['label'] == 1]])
wordcloud = WordCloud(width=800, height=500,
random_state=21, max_font_size=110).generate(negative_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
# WORD2VEC
from gensim.models import FastText
W2V_SIZE = 300
W2V_WINDOW = 7
W2V_EPOCH = 32
W2V_MIN_COUNT = 1

f2t_model = FastText(size=W2V_SIZE,
                     window=W2V_WINDOW,
                     min_count=W2V_MIN_COUNT,
                     workers=4, iter=1000)

# %%
# %%time
documents = [_text.split() for _text in combi.tidy_tweet]
# Out:
# CPU times: user 93.6 ms, sys: 103 ms, total: 197 ms
# Wall time: 241 ms

# %%
# %%time
f2t_model.build_vocab(documents)
# Out:
# CPU times: user 22.1 s, sys: 17.3 s, total: 39.4 s
# Wall time: 1min 6s

# %%
# %%time
words = f2t_model.wv.vocab.keys()
vocab_size = len(words)
print("Vocab size", vocab_size)
f2t_model.train(documents, total_examples=len(documents), epochs=W2V_EPOCH)
# Out:
# Vocab size 22799
# CPU times: user 6min 22s, sys: 4.29 s, total: 6min 26s
# Wall time: 1min 55s

# %%
embed_dim = 300 # how big is each word vector
max_features = vocab_size # how many unique words to use (i.e num rows in embedding vector)
max_seq_len = max_seq_len # max number of words in a question to use

# %%
df_train=combi[:len(train)]
df_test=combi[len(train):]

# %%
tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(combi.tidy_tweet)
word_index = tokenizer.word_index
word_seq_train = tokenizer.texts_to_sequences(df_train['tidy_tweet'])
word_seq_test = tokenizer.texts_to_sequences(df_test['tidy_tweet'])
word_index = tokenizer.word_index
print("dictionary size: ", len(word_index))

#pad sequences
word_seq_train = pad_sequences(word_seq_train, maxlen=max_seq_len)
word_seq_test = pad_sequences(word_seq_test, maxlen=max_seq_len)
# Out:
# dictionary size:  22797

# %%
encoder = LabelEncoder()
encoder.fit(df_train.label.tolist())
y_train = encoder.transform(df_train.label.tolist())
y_train = y_train.reshape(-1,1)
print("y_train",y_train.shape)
# Out:
# y_train (43172, 1)

# %%
df_test.drop('label',1,inplace=True)
# Out:
# /Users/subir/pythonenv/default/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_test.head()
# Out:
#           id  \
# 43172  31963
# 43173  31964
# 43174  31965
# 43175  31966
# 43176  31967
#
#                                                                                                                                                 tweet  \
# 43172  #studiolife #aislife #requires #passion #dedication #willpower   to find #newmaterialsâ¦
# 43173   @user #white #supremacists want everyone to see the new â  #birdsâ #movie â and hereâs why
# 43174  safe ways to heal your #acne!!    #altwaystoheal #healthy   #healing!!
# 43175  is the hp and the cursed child book up for reservations already? if yes, where? if no, when? ððð   #harrypotter #pottermore #favorite
# 43176    3rd #bihday to my amazing, hilarious #nephew eli ahmir! uncle dave loves you and missesâ¦
#
#                                                                           tidy_tweet  \
# 43172  studio life be life require passion dedication willpower find new material
# 43173  white supremacist want everyone see new bird movie
# 43174  safe way heal acne alt way to heal healthy healing
# 43175  hp curse child book reservation already yes harry potter potter more favorite
# 43176  rd bih day amazing hilarious nephew eli ah mir uncle dave love miss
#
#        doc_len
# 43172  11
# 43173  8
# 43174  10
# 43175  12
# 43176  13

# %%
print('preparing embedding matrix...')
words_not_found = []
nb_words = min(max_features, len(word_index)+1)
embedding_matrix = np.zeros((nb_words, embed_dim))
for word, i in word_index.items():
    if i >= nb_words:
        continue
    embedding_vector = f2t_model.wv.get_vector(word)
    if (embedding_vector is not None) and len(embedding_vector) > 0:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
    else:
        words_not_found.append(word)
print('number of null word embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))
# Out:
# preparing embedding matrix...
# number of null word embeddings: 1

# %%
embedding_layer = Embedding(nb_words, 300, weights=[embedding_matrix], input_length=max_seq_len, trainable=False)

# %%
import keras.backend as K

# %%
# build network
from keras.utils.generic_utils import get_custom_objects
class Swish(Activation):
    
    def __init__(self, activation, **kwargs):
        super(Swish, self).__init__(activation, **kwargs)
        self.__name__ = 'swish'
        
def swish(x):
    return K.sigmoid(x) * x

# %%
model = Sequential()
get_custom_objects().update({'swish': Swish(swish)})
model.add(embedding_layer)
model.add(Bidirectional(LSTM(256, dropout=0.2, recurrent_dropout=0.2,return_sequences=True)))
model.add(TimeDistributed(Dense(128, use_bias=True)))
model.add(Flatten())
model.add(Dense(100))
model.add(BatchNormalization())
model.add(Activation('swish'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 13, 300)           6839400
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 13, 512)           1140736
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 13, 128)           65664
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1664)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 100)               166500
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 100)               400
# _________________________________________________________________
# activation_3 (Activation)    (None, 100)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 8,212,801
# Trainable params: 1,373,201
# Non-trainable params: 6,839,600
# _________________________________________________________________

# %%
model.compile(optimizer='nadam',metrics=['accuracy'],loss='binary_crossentropy')

# %%
filepath = 'ModelCheckpoint/Bi_LSTM_f2t.{epoch:02d}-{val_accuracy:.3f}.hdf5'
callbacks = [ReduceLROnPlateau(monitor='val_accuracy', patience=10, cooldown=5, verbose=1, factor=0.5),
             ModelCheckpoint(filepath, monitor='val_accuracy',
                             verbose=1, mode='max',save_best_only=True)]

# %%
# %%time
history = model.fit(word_seq_train, y_train,
                    batch_size=32,
                    epochs=50,
                    validation_split=0.2,
                    verbose=1,
                    callbacks=callbacks,shuffle=True)
# Out:
# Train on 34537 samples, validate on 8635 samples
# Epoch 1/50
# 34537/34537 [==============================] - 77s 2ms/step - loss: 0.2025 - accuracy: 0.9222 - val_loss: 0.4365 - val_accuracy: 0.8234
#
# Epoch 00001: val_accuracy improved from -inf to 0.82339, saving model to ModelCheckpoint/Bi_LSTM_f2t.01-0.823.hdf5
# Epoch 2/50
# 34537/34537 [==============================] - 81s 2ms/step - loss: 0.1089 - accuracy: 0.9602 - val_loss: 0.2118 - val_accuracy: 0.9223
#
# Epoch 00002: val_accuracy improved from 0.82339 to 0.92229, saving model to ModelCheckpoint/Bi_LSTM_f2t.02-0.922.hdf5
# Epoch 3/50
# 34537/34537 [==============================] - 83s 2ms/step - loss: 0.0704 - accuracy: 0.9747 - val_loss: 0.1535 - val_accuracy: 0.9470
#
# Epoch 00003: val_accuracy improved from 0.92229 to 0.94696, saving model to ModelCheckpoint/Bi_LSTM_f2t.03-0.947.hdf5
# Epoch 4/50
# 34537/34537 [==============================] - 82s 2ms/step - loss: 0.0480 - accuracy: 0.9829 - val_loss: 0.0578 - val_accuracy: 0.9786
#
# Epoch 00004: val_accuracy improved from 0.94696 to 0.97858, saving model to ModelCheckpoint/Bi_LSTM_f2t.04-0.979.hdf5
# Epoch 5/50
# 34537/34537 [==============================] - 87s 3ms/step - loss: 0.0375 - accuracy: 0.9862 - val_loss: 0.0392 - val_accuracy: 0.9867
#
# Epoch 00005: val_accuracy improved from 0.97858 to 0.98668, saving model to ModelCheckpoint/Bi_LSTM_f2t.05-0.987.hdf5
# Epoch 6/50
# 34537/34537 [==============================] - 89s 3ms/step - loss: 0.0345 - accuracy: 0.9878 - val_loss: 0.0273 - val_accuracy: 0.9915
#
# Epoch 00006: val_accuracy improved from 0.98668 to 0.99155, saving model to ModelCheckpoint/Bi_LSTM_f2t.06-0.992.hdf5
# Epoch 7/50
# 34537/34537 [==============================] - 88s 3ms/step - loss: 0.0268 - accuracy: 0.9905 - val_loss: 0.0421 - val_accuracy: 0.9865
#
# Epoch 00007: val_accuracy did not improve from 0.99155
# Epoch 8/50
# 34537/34537 [==============================] - 88s 3ms/step - loss: 0.0245 - accuracy: 0.9913 - val_loss: 0.0264 - val_accuracy: 0.9934
#
# Epoch 00008: val_accuracy improved from 0.99155 to 0.99340, saving model to ModelCheckpoint/Bi_LSTM_f2t.08-0.993.hdf5
# Epoch 9/50
# 34537/34537 [==============================] - 88s 3ms/step - loss: 0.0254 - accuracy: 0.9913 - val_loss: 0.0309 - val_accuracy: 0.9917
#
# Epoch 00009: val_accuracy did not improve from 0.99340
# Epoch 10/50
# 34537/34537 [==============================] - 87s 3ms/step - loss: 0.0213 - accuracy: 0.9926 - val_loss: 0.0127 - val_accuracy: 0.9955
#
# Epoch 00010: val_accuracy improved from 0.99340 to 0.99548, saving model to ModelCheckpoint/Bi_LSTM_f2t.10-0.995.hdf5
# Epoch 11/50
# 34537/34537 [==============================] - 87s 3ms/step - loss: 0.0218 - accuracy: 0.9924 - val_loss: 0.0293 - val_accuracy: 0.9918
#
# Epoch 00011: val_accuracy did not improve from 0.99548
# Epoch 12/50
# 34537/34537 [==============================] - 87s 3ms/step - loss: 0.0180 - accuracy: 0.9935 - val_loss: 0.0201 - val_accuracy: 0.9935
#
# Epoch 00012: val_accuracy did not improve from 0.99548
# Epoch 13/50
# 34537/34537 [==============================] - 87s 3ms/step - loss: 0.0191 - accuracy: 0.9935 - val_loss: 0.0133 - val_accuracy: 0.9955
#
# Epoch 00013: val_accuracy did not improve from 0.99548
# Epoch 14/50
# 34537/34537 [==============================] - 86s 2ms/step - loss: 0.0194 - accuracy: 0.9933 - val_loss: 0.0131 - val_accuracy: 0.9946
#
# Epoch 00014: val_accuracy did not improve from 0.99548
# Epoch 15/50
# 34537/34537 [==============================] - 86s 2ms/step - loss: 0.0175 - accuracy: 0.9943 - val_loss: 0.0145 - val_accuracy: 0.9955
#
# Epoch 00015: val_accuracy did not improve from 0.99548
# Epoch 16/50
# 34537/34537 [==============================] - 85s 2ms/step - loss: 0.0162 - accuracy: 0.9942 - val_loss: 0.0119 - val_accuracy: 0.9941
#
# Epoch 00016: val_accuracy did not improve from 0.99548
# Epoch 17/50
# 34537/34537 [==============================] - 85s 2ms/step - loss: 0.0150 - accuracy: 0.9945 - val_loss: 0.0098 - val_accuracy: 0.9968
#
# Epoch 00017: val_accuracy improved from 0.99548 to 0.99676, saving model to ModelCheckpoint/Bi_LSTM_f2t.17-0.997.hdf5
# Epoch 18/50
# 34537/34537 [==============================] - 85s 2ms/step - loss: 0.0149 - accuracy: 0.9946 - val_loss: 0.0099 - val_accuracy: 0.9964
#
# Epoch 00018: val_accuracy did not improve from 0.99676
# Epoch 19/50
# 34537/34537 [==============================] - 84s 2ms/step - loss: 0.0158 - accuracy: 0.9939 - val_loss: 0.0179 - val_accuracy: 0.9966
#
# Epoch 00019: val_accuracy did not improve from 0.99676
# Epoch 20/50
# 34537/34537 [==============================] - 85s 2ms/step - loss: 0.0140 - accuracy: 0.9953 - val_loss: 0.0115 - val_accuracy: 0.9972
#
# Epoch 00020: val_accuracy improved from 0.99676 to 0.99722, saving model to ModelCheckpoint/Bi_LSTM_f2t.20-0.997.hdf5
# Epoch 21/50
# 34537/34537 [==============================] - 84s 2ms/step - loss: 0.0172 - accuracy: 0.9938 - val_loss: 0.0069 - val_accuracy: 0.9978
#
# Epoch 00021: val_accuracy improved from 0.99722 to 0.99780, saving model to ModelCheckpoint/Bi_LSTM_f2t.21-0.998.hdf5
# Epoch 22/50
# 34537/34537 [==============================] - 84s 2ms/step - loss: 0.0139 - accuracy: 0.9948 - val_loss: 0.0139 - val_accuracy: 0.9955
#
# Epoch 00022: val_accuracy did not improve from 0.99780
# Epoch 23/50
# 34537/34537 [==============================] - 83s 2ms/step - loss: 0.0154 - accuracy: 0.9949 - val_loss: 0.0053 - val_accuracy: 0.9981
#
# Epoch 00023: val_accuracy improved from 0.99780 to 0.99815, saving model to ModelCheckpoint/Bi_LSTM_f2t.23-0.998.hdf5
# Epoch 24/50
# 34537/34537 [==============================] - 84s 2ms/step - loss: 0.0134 - accuracy: 0.9949 - val_loss: 0.0091 - val_accuracy: 0.9976
#
# Epoch 00024: val_accuracy did not improve from 0.99815
# Epoch 25/50
# 34537/34537 [==============================] - 83s 2ms/step - loss: 0.0132 - accuracy: 0.9955 - val_loss: 0.0092 - val_accuracy: 0.9966
#
# Epoch 00025: val_accuracy did not improve from 0.99815
# Epoch 26/50
# 34537/34537 [==============================] - 83s 2ms/step - loss: 0.0121 - accuracy: 0.9958 - val_loss: 0.0081 - val_accuracy: 0.9964
#
# Epoch 00026: val_accuracy did not improve from 0.99815
# Epoch 27/50
# 34537/34537 [==============================] - 83s 2ms/step - loss: 0.0139 - accuracy: 0.9952 - val_loss: 0.0074 - val_accuracy: 0.9978
#
# Epoch 00027: val_accuracy did not improve from 0.99815
# Epoch 28/50
# 34537/34537 [==============================] - 83s 2ms/step - loss: 0.0130 - accuracy: 0.9953 - val_loss: 0.0060 - val_accuracy: 0.9976
#
# Epoch 00028: val_accuracy did not improve from 0.99815
# Epoch 29/50
# 34537/34537 [==============================] - 83s 2ms/step - loss: 0.0134 - accuracy: 0.9961 - val_loss: 0.0077 - val_accuracy: 0.9970
#
# Epoch 00029: val_accuracy did not improve from 0.99815
# Epoch 30/50
# 34537/34537 [==============================] - 81s 2ms/step - loss: 0.0143 - accuracy: 0.9947 - val_loss: 0.0076 - val_accuracy: 0.9970
#
# Epoch 00030: val_accuracy did not improve from 0.99815
# Epoch 31/50
# 34537/34537 [==============================] - 81s 2ms/step - loss: 0.0126 - accuracy: 0.9958 - val_loss: 0.0061 - val_accuracy: 0.9976
#
# Epoch 00031: val_accuracy did not improve from 0.99815
# Epoch 32/50
# 34537/34537 [==============================] - 81s 2ms/step - loss: 0.0110 - accuracy: 0.9956 - val_loss: 0.0046 - val_accuracy: 0.9981
#
# Epoch 00032: val_accuracy did not improve from 0.99815
# Epoch 33/50
# 34537/34537 [==============================] - 81s 2ms/step - loss: 0.0126 - accuracy: 0.9952 - val_loss: 0.0060 - val_accuracy: 0.9976
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 00033: val_accuracy did not improve from 0.99815
# Epoch 34/50
# 34537/34537 [==============================] - 81s 2ms/step - loss: 0.0103 - accuracy: 0.9964 - val_loss: 0.0034 - val_accuracy: 0.9981
#
# Epoch 00034: val_accuracy did not improve from 0.99815
# Epoch 35/50
# 34537/34537 [==============================] - 81s 2ms/step - loss: 0.0084 - accuracy: 0.9968 - val_loss: 0.0063 - val_accuracy: 0.9972
#
# Epoch 00035: val_accuracy did not improve from 0.99815
# Epoch 36/50
# 34537/34537 [==============================] - 82s 2ms/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.0052 - val_accuracy: 0.9976
#
# Epoch 00036: val_accuracy did not improve from 0.99815
# Epoch 37/50
# 34537/34537 [==============================] - 71s 2ms/step - loss: 0.0077 - accuracy: 0.9973 - val_loss: 0.0055 - val_accuracy: 0.9976
#
# Epoch 00037: val_accuracy did not improve from 0.99815
# Epoch 38/50
# 34537/34537 [==============================] - 73s 2ms/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 0.0051 - val_accuracy: 0.9976
#
# Epoch 00038: val_accuracy did not improve from 0.99815
# Epoch 39/50
# 34537/34537 [==============================] - 71s 2ms/step - loss: 0.0061 - accuracy: 0.9979 - val_loss: 0.0072 - val_accuracy: 0.9976
#
# Epoch 00039: val_accuracy did not improve from 0.99815
# Epoch 40/50
# 34537/34537 [==============================] - 73s 2ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.0022 - val_accuracy: 0.9981
#
# Epoch 00040: val_accuracy did not improve from 0.99815
# Epoch 41/50
# 34537/34537 [==============================] - 72s 2ms/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.0029 - val_accuracy: 0.9981
#
# Epoch 00041: val_accuracy did not improve from 0.99815
# Epoch 42/50
# 34537/34537 [==============================] - 72s 2ms/step - loss: 0.0048 - accuracy: 0.9983 - val_loss: 0.0061 - val_accuracy: 0.9976
#
# Epoch 00042: val_accuracy did not improve from 0.99815
# Epoch 43/50
# 34537/34537 [==============================] - 72s 2ms/step - loss: 0.0052 - accuracy: 0.9979 - val_loss: 0.0032 - val_accuracy: 0.9976
#
# Epoch 00043: val_accuracy did not improve from 0.99815
# Epoch 44/50
# 34537/34537 [==============================] - 72s 2ms/step - loss: 0.0047 - accuracy: 0.9982 - val_loss: 0.0088 - val_accuracy: 0.9976
#
# Epoch 00044: val_accuracy did not improve from 0.99815
# Epoch 45/50
# 34537/34537 [==============================] - 71s 2ms/step - loss: 0.0069 - accuracy: 0.9980 - val_loss: 0.0050 - val_accuracy: 0.9976
#
# Epoch 00045: val_accuracy did not improve from 0.99815
# Epoch 46/50
# 34537/34537 [==============================] - 72s 2ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.0014 - val_accuracy: 1.0000
#
# Epoch 00046: val_accuracy improved from 0.99815 to 1.00000, saving model to ModelCheckpoint/Bi_LSTM_f2t.46-1.000.hdf5
# Epoch 47/50
# 34537/34537 [==============================] - 71s 2ms/step - loss: 0.0051 - accuracy: 0.9980 - val_loss: 0.0037 - val_accuracy: 0.9976
#
# Epoch 00047: val_accuracy did not improve from 1.00000
# Epoch 48/50
# 34537/34537 [==============================] - 72s 2ms/step - loss: 0.0045 - accuracy: 0.9984 - val_loss: 0.0040 - val_accuracy: 0.9976
#
# Epoch 00048: val_accuracy did not improve from 1.00000
# Epoch 49/50
# 34537/34537 [==============================] - 72s 2ms/step - loss: 0.0047 - accuracy: 0.9983 - val_loss: 0.0056 - val_accuracy: 0.9976
#
# Epoch 00049: val_accuracy did not improve from 1.00000
# Epoch 50/50
# 34537/34537 [==============================] - 72s 2ms/step - loss: 0.0058 - accuracy: 0.9977 - val_loss: 0.0045 - val_accuracy: 0.9976
#
# Epoch 00050: val_accuracy did not improve from 1.00000
# CPU times: user 3h 13min 4s, sys: 26min 21s, total: 3h 39min 25s
# Wall time: 1h 7min 20s

# %%
from keras.models import load_model
model = load_model('ModelCheckpoint/Bi_LSTM_f2t.12-1.000.hdf5',custom_objects={'swish': Swish(swish)})

# %%
pred=model.predict(word_seq_test)

# %%
def decode_sentiment(prediction_prob):
    sentiment = []
    for idx, val in enumerate(prediction_prob):
        if val>0.5:
            sentiment.append(1)
        else:
            sentiment.append(0)
    print('Done')
    return sentiment

# %%
sentiment = decode_sentiment(pred)
# Out:
# Done

# %%
Submission = pd.DataFrame()
Submission['id']=df_test['id']
Submission['label']=sentiment

# %%
Submission.to_csv('Submission_BiLSTM_Fasttext.csv',index=False)
